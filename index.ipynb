# %% [markdown]
# # Yelp API - Lab
#
# The previously deployed lab on working around building a GIS with Yelp API and Folium can be found [here](https://github.com/learn-co-curriculum/dsc-2-15-10-yelp-api-gis-lab/tree/a56358c2d0c2daf569a5f50937c4c27463aadb1a) (not relevant for new students).
#
#
# ## Introduction
#
# Now that we've seen how the Yelp API works, and some basic Folium visualizations its time to put those skills to work in order to create a working map! Taking things a step further, you'll also independently explore how to perform pagination in order to retrieve a full results set from the Yelp API!
#
# ## Objectives
#
# You will be able to:
# * Create HTTP requests to get data from Yelp API
# * Parse HTTP responses and perform data analysis on the data returned
# * Perform pagination to retrieve troves of data!
# * Create a simple geographical system on to view information about selected businesses, at a given location.

# %% [markdown]
# ## Problem Introduction
#
# You've now worked with some API calls, but we have yet to see how to retrieve a more complete dataset in a programmatic manner. Returning to the Yelp API, the [documentation](https://www.yelp.com/developers/documentation/v3/business_search) also provides us details regarding the API limits. These often include details about the number of requests a user is allowed to make within a specified time limit and the maximum number of results to be returned. In this case, we are told that any request has a maximum of 50 results per request and defaults to 20. Furthermore, any search will be limited to a total of 1000 results. To retrieve all 1000 of these results, we would have to page through the results piece by piece, retriving 50 at a time. Processes such as these are often refered to as pagination.
#
# In this lab, you will define a search and then paginate over the results to retrieve all of the results. You'll then parse these responses as a DataFrame (for further exploration) and create a map using Folium to visualize the results geographically.

# %% [markdown]
# ## Part I - Make the Initial Request
#
# Start by making an initial request to the Yelp API. Your search must include at least 2 parameters: **term** and **location**. For example, you might search for pizza restaurants in NYC. The term and location is up to you, but make the request below.

# %%
import requests
import json
import pandas as pd
import numpy as np
import time

# %%
client_id = "0od3VXrFtzCRgcKL4GtKHA"
api_key = "sVAxWQR2mJyptyIyDRqXhR24NdrRVH3simx7bJSQqc7GXIEl2sj2sB9obPMa5wGPGCJh_jVf-y2dCs9CeVtrooh0GutAGh29c0tsz1mMun0vxLDDw0YQzGPe33KSXHYx"

# %%
term = "Cookies"
location = "NYC"
search_limit = 10

url = 'https://api.yelp.com/v3/businesses/search'

headers = {
        'Authorization': 'Bearer {}'.format(api_key),
    }

url_params = {
                'term': term.replace(' ', '+'),
                'location': location.replace(' ', '+'),
                'limit': search_limit
            }
response = requests.get(url, headers=headers, params=url_params)
print(response)
print(type(response.text))
print(response.text[:1000])
# Out:
# <Response [200]>
# <class 'str'>
# {"businesses": [{"id": "H4jJ7XB3CetIr1pg56CczQ", "alias": "levain-bakery-new-york", "name": "Levain Bakery", "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/9uUdfbEHUB4D-4s_RVA9zw/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/levain-bakery-new-york?adjust_creative=0od3VXrFtzCRgcKL4GtKHA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0od3VXrFtzCRgcKL4GtKHA", "review_count": 7388, "categories": [{"alias": "bakeries", "title": "Bakeries"}], "rating": 4.5, "coordinates": {"latitude": 40.7799404643263, "longitude": -73.980282552649}, "transactions": [], "price": "$$", "location": {"address1": "167 W 74th St", "address2": "", "address3": "", "city": "New York", "zip_code": "10023", "country": "US", "state": "NY", "display_address": ["167 W 74th St", "New York, NY 10023"]}, "phone": "+12128746080", "display_phone": "(212) 874-6080", "distance": 8367.197123060287}, {"id": "jz_FnuRpCNzfwwHHQ6Nbeg", "alias": "schmackarys-new-york", "name": "Schmackary'

# %% [markdown]
# ## Pagination
#
# Now that you have an initial response, you can examine the contents of the json container. For example, you might start with ```response.josn().keys()```. Here, you'll see a key for `'total'`, which tells you the full number of matching results given your query parameters. Write a loop (or ideally a function) which then makes successive API calls using the offset parameter to retrieve all of the results (or 5000 for a particularly large result set) for the original query. As you do this, be mindful of how you store the data. Your final goal will be to reformat the data concerning the businesses themselves into a pandas DataFrame from the json objects.
#
# **Note: be mindful of the API rate limits. You can only make 5000 requests per day, and are also can make requests too fast. Start prototyping small before running a loop that could be faulty. You can also use time.sleep(n) to add delays. For more details see https://www.yelp.com/developers/documentation/v3/rate_limiting.**

# %%
def make_api_request(term, location):
    url = 'https://api.yelp.com/v3/businesses/search'
    headers = {'Authorization': 'Bearer {}'.format(api_key),}
    for i in range(3):
        url_params = {
            'term': term.replace(' ', '+'),
            'location': location.replace(' ', '+'),
            'limit': 50,
            'offset': i * 50
            }
        response = requests.get(url, headers=headers, params=url_params)
    return response

# %%
yelp_1 = make_api_request("cookie", "NYC")

# %%
yelp_1 = yelp_1.json()

# %%
print(yelp_1)
# Out:
# {'businesses': [{'id': 'ae8AqaVJ0sUHT4eJwMq-Pg', 'alias': 'spot-dessert-bar-flushing', 'name': 'Spot Dessert Bar', 'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/
, 'transactions': ['pickup', 'delivery'], 'price': '$', 'location': {'address1': '123 E 7th St', 'address2': '', 'address3': '', 'city': 'New York', 'zip_code': '10009', 'country': 'US', 'state': 'NY', 'display_address': ['123 E 7th St', 'New York, NY 10009']}, 'phone': '+12126772880', 'display_phone': '(212) 677-2880', 'distance': 2491.864637411364}, {'id': 'WkmqGh7NF6VUz43UTTFvMg', 'alias': 'f-monteleone-bakery-and-cafe-brooklyn', 'name': 'F Monteleone B ...

# %% [markdown]
# ## Exploratory Analysis
#
# Take the restaurants from the previous question and do an intial exploratory analysis. At minimum, this should include looking at the distribution of features such as price, rating and number of reviews as well as the relations between these dimensions.

# %%
df1 = pd.DataFrame.from_dict(yelp_1['businesses'])
# df2 = pd.DataFrame.from_dict(yelp_2['businesses'])
# df3 = pd.DataFrame.from_dict(yelp_3['businesses'])
# df4 = pd.DataFrame.from_dict(yelp_4['businesses'])
# df5 = pd.DataFrame.from_dict(yelp_5['businesses'])
# df6 = pd.DataFrame.from_dict(yelp_6['businesses'])
# df = pd.concat([df1, df2, df3, df4, df5, df6])
df1
# Out:
#                                             alias  \
# 0                          levain-bakery-new-york
# 1                  gooey-on-the-inside-new-york-4
# 2                            schmackarys-new-york
# 3                                chip-nyc-astoria
# 4                        levain-bakery-new-york-3
# 5                              chip-nyc-astoria-4
# 6                 the-cookie-connect-bloomfield-2
# 7                             city-cakes-new-york
# 8                         bens-cookies-new-york-4
# 9                      bang-cookies-jersey-city-3
# 10                sofia-and-grace-cookie-brooklyn
# 11                    milk-and-cookies-new-york-2
# 12                      one-girl-cookies-brooklyn
# 13                      chip-nyc-long-island-city
# 14                   insomnia-cookies-new-york-13
# 15                       levain-bakery-new-york-5
# 16                       fat-cat-kitchen-new-york
# 17                 buttermilk-bakeshop-brooklyn-2
# 18  birdbath-neighborhood-green-bakery-new-york-9
# 19               golden-glow-cookie-company-bronx
# 20                        the-good-batch-brooklyn
# 21                              ovenly-brooklyn-9
# 22                      woops-bakeshop-brooklyn-4
# 23                   the-cookie-jar-staten-island
# 24                dominique-ansel-bakery-new-york
# 25                    insomnia-cookies-new-york-9
# 26                   insomnia-cookies-new-york-11
# 27                              ovenly-brooklyn-8
# 28                  madonia-brothers-bakery-bronx
# 29   la-bonbonnieres-cookie-jar-bakery-woodbridge
# 30                 sweet-corner-bakeshop-new-york
# 31              jacques-torres-chocolate-brooklyn
# 32                   butter-and-scotch-brooklyn-2
# 33         sweet-sweet-sues-cupcake-cafe-new-york
# 34                    mah-ze-dahr-bakery-new-york
# 35                            baking-mama-hoboken
# 36                             orwashers-new-york
# 37                    one-girl-cookies-brooklyn-3
# 38                 krumville-bake-shop-brooklyn-2
# 39                 two-little-red-hens-new-york-4
# 40                 brooklyn-sweet-spot-brooklyn-2
# 41                    sugar-and-water-nyc-astoria
# 42                   insomnia-cookies-new-york-10
# 43                                ovenly-brooklyn
# 44                      boomshakalaka-ny-brooklyn
# 45                                 baked-new-york
# 46                    insomnia-cookies-new-york-2
# 47                           mias-bakery-brooklyn
# 48                  the-french-workshop-bayside-2
# 49                   gansevoort-market-new-york-2
#
#                                            categories  \
# 0        [{'alias': 'bakeries', 'title': 'Bakeries'}]
# 1   [{'alias': 'desserts', 'title': 'Desserts'}, {...
# 2   [{'alias': 'desserts', 'title': 'Desserts'}, {...
# 3   [{'alias': 'bakeries', 'title': 'Bakeries'}, {...
# 4        [{'alias': 'bakeries', 'title': 'Bakeries'}]
# 5        [{'alias': 'bakeries', 'title': 'Bakeries'}]
# 6        [{'alias': 'desserts', 'title': 'Desserts'}]
# 7   [{'alias': 'desserts', 'title': 'Desserts'}, {...
# 8        [{'alias': 'bakeries', 'title': 'Bakeries'}]
# 9   [{'alias': 'bakeries', 'title': 'Bakeries'}, {...
# 10  [{'alias': 'coffee', 'title': 'Coffee & Tea'},...
# 11       [{'alias': 'bakeries', 'title': 'Bakeries'}]
# 12  [{'alias': 'bakeries', 'title': 'Bakeries'}, {...
# 13       [{'alias': 'desserts', 'title': 'Desserts'}]
# 14  [{'alias': 'desserts', 'title': 'Desserts'}, {...
# 15  [{'alias': 'bakeries', 'title': 'Bakeries'}, {...
# 16  [{'alias': 'sandwiches', 'title': 'Sandwiches'...
# 17       [{'alias': 'bakeries', 'title': 'Bakeries'}]
# 18       [{'alias': 'bakeries', 'title': 'Bakeries'}]
# 19       [{'alias': 'bakeries', 'title': 'Bakeries'}]
# 20  [{'alias': 'bakeries', 'title': 'Bakeries'}, {...
# 21       [{'alias': 'bakeries', 'title': 'Bakeries'}]
# 22       [{'alias': 'macarons', 'title': 'Macarons'}]
# 23       [{'alias': 'bakeries', 'title': 'Bakeries'}]
# 24  [{'alias': 'bakeries', 'title': 'Bakeries'}, {...
# 25  [{'alias': 'bakeries', 'title': 'Bakeries'}, {...
# 26  [{'alias': 'bakeries', 'title': 'Bakeries'}, {...
# 27       [{'alias': 'bakeries', 'title': 'Bakeries'}]
# 28       [{'alias': 'bakeries', 'title': 'Bakeries'}]
# 29  [{'alias': 'bakeries', 'title': 'Bakeries'}, {...
# 30  [{'alias': 'coffee', 'title': 'Coffee & Tea'},...
# 31  [{'alias': 'chocolate', 'title': 'Chocolatiers...
# 32  [{'alias': 'desserts', 'title': 'Desserts'}, {...
# 33       [{'alias': 'bakeries', 'title': 'Bakeries'}]
# 34  [{'alias': 'bakeries', 'title': 'Bakeries'}, {...
# 35  [{'alias': 'bakeries', 'title': 'Bakeries'}, {...
# 36       [{'alias': 'bakeries', 'title': 'Bakeries'}]
# 37  [{'alias': 'bakeries', 'title': 'Bakeries'}, {...
# 38  [{'alias': 'bakeries', 'title': 'Bakeries'}, {...
# 39  [{'alias': 'bakeries', 'title': 'Bakeries'}, {...
# 40  [{'alias': 'bakeries', 'title': 'Bakeries'}, {...
# 41  [{'alias': 'donuts', 'title': 'Donuts'}, {'ali...
# 42  [{'alias': 'bakeries', 'title': 'Bakeries'}, {...
# 43  [{'alias': 'bakeries', 'title': 'Bakeries'}, {...
# 44       [{'alias': 'desserts', 'title': 'Desserts'}]
# 45  [{'alias': 'bakeries', 'title': 'Bakeries'}, {...
# 46  [{'alias': 'bakeries', 'title': 'Bakeries'}, {...
# 47  [{'alias': 'bakeries', 'title': 'Bakeries'}, {...
# 48       [{'alias': 'bakeries', 'title': 'Bakeries'}]
# 49  [{'alias': 'gourmet', 'title': 'Specialty Food'}]
#
#                                           coordinates   display_phone  \
# 0   {'latitude': 40.7799404643263, 'longitude': -7...  (212) 874-6080
# 1      {'latitude': 40.72063, 'longitude': -73.99275}  (646) 972-0409
# 2   {'latitude': 40.760153883881, 'longitude': -73...  (646) 801-9866
# 3   {'latitude': 40.7655337630129, 'longitude': -7...  (917) 745-0101
# 4   {'latitude': 40.8049739, 'longitude': -73.9551...  (646) 455-0952
# 5   {'latitude': 40.7755748, 'longitude': -73.9095...  (929) 522-0800
# 6   {'latitude': 40.8366154, 'longitude': -74.1636...  (201) 822-5339
# 7      {'latitude': 40.74206, 'longitude': -73.99999}  (646) 688-2286
# 8     {'latitude': 40.732962, 'longitude': -73.99093}  (646) 590-1156
# 9      {'latitude': 40.75567, 'longitude': -74.04607}  (888) 834-8885
# 10   {'latitude': 40.6844899, 'longitude': -73.92289}  (718) 450-8034
# 11  {'latitude': 40.731812157368, 'longitude': -74...  (212) 243-1640
# 12   {'latitude': 40.687328, 'longitude': -73.990465}  (212) 675-4996
# 13     {'latitude': 40.75009, 'longitude': -73.94062}  (917) 745-0101
# 14   {'latitude': 40.70377, 'longitude': -74.0104099}  (929) 258-7762
# 15   {'latitude': 40.781532, 'longitude': -73.979286}  (212) 874-6080
# 16     {'latitude': 40.73314, 'longitude': -73.98607}  (212) 235-1994
# 17  {'latitude': 40.6749461087063, 'longitude': -7...  (347) 987-3941
# 18     {'latitude': 40.72596, 'longitude': -74.00143}  (646) 556-7720
# 19     {'latitude': 40.87638, 'longitude': -73.83959}  (718) 379-6223
# 20     {'latitude': 40.68254, 'longitude': -73.96331}  (718) 622-4000
# 21     {'latitude': 40.71909, 'longitude': -73.96247}  (888) 899-2213
# 22   {'latitude': 40.717529, 'longitude': -73.956409}  (718) 384-4410
# 23  {'latitude': 40.6261618, 'longitude': -74.1305...  (718) 448-3500
# 24     {'latitude': 40.72522, 'longitude': -74.00291}  (212) 219-2773
# 25  {'latitude': 40.8034309090793, 'longitude': -7...  (917) 935-4257
# 26  {'latitude': 40.7297607, 'longitude': -74.0006...  (917) 877-0659
# 27     {'latitude': 40.68119, 'longitude': -73.97573}  (888) 899-2213
# 29  https://s3-media3.fl.yelpcdn.com/bphoto/rHqDTP...      False
# 30  https://s3-media1.fl.yelpcdn.com/bphoto/zpLA5u...      False
# 31  https://s3-media4.fl.yelpcdn.com/bphoto/-RuZ7q...      False
# 32  https://s3-media4.fl.yelpcdn.com/bphoto/yGpySZ...      False
# 33  https://s3-media4.fl.yelpcdn.com/bphoto/GPl_s-...      False
# 34  https://s3-media3.fl.yelpcdn.com/bphoto/sq8hFN...      False
# 35  https://s3-media2.fl.yelpcdn.com/bphoto/yias_d...      False
# 36  https://s3-media1.fl.yelpcdn.com/bphoto/F6VeUH...      False
# 37  https://s3-media4.fl.yelpcdn.com/bphoto/nLAlu4...      False
# 38  https://s3-media1.fl.yelpcdn.com/bphoto/wA5bQ-...      False
# 39  https://s3-media3.fl.yelpcdn.com/bphoto/gF02Oh...      False
# 40  https://s3-media3.fl.yelpcdn.com/bphoto/mQKmKp...      False
# 41  https://s3-media2.fl.yelpcdn.com/bphoto/JAqG5r...      False
# 42  https://s3-media2.fl.yelpcdn.com/bphoto/0vkMh5...      False
# 43  https://s3-media4.fl.yelpcdn.com/bphoto/TRAVYj...      False
# 44  https://s3-media1.fl.yelpcdn.com/bphoto/xsXlqb...      False
# 45  https://s3-media4.fl.yelpcdn.com/bphoto/1KZGBM...      False
# 46  https://s3-media2.fl.yelpcdn.com/bphoto/2tXx_c...      False
# 47  https://s3-media1.fl.yelpcdn.com/bphoto/CjvLo6...      False
# 48  https://s3-media1.fl.yelpcdn.com/bphoto/lWWbmJ...      False
# 49  https://s3-media1.fl.yelpcdn.com/bphoto/J3Jwqk...      False
#
#                                              location  \
# 0   {'address1': '167 W 74th St', 'address2': '', ...
# 1   {'address1': '163 Chrystie St', 'address2': 'B...
# 2   {'address1': '362 W 45th St', 'address2': '', ...
# 3   {'address1': '30-06 34th St', 'address2': None...
# 4   {'address1': '2167 Frederick Douglass Blvd', '...
# 5   {'address1': '22-04 33rd St', 'address2': '', ...
# 6   {'address1': '405 W Passaic Ave', 'address2': ...
# 7   {'address1': '251 W 18th St', 'address2': '', ...
# 8   {'address1': '822 Broadway', 'address2': '', '...
# 9   {'address1': '1183 Summit Ave', 'address2': No...
# 10  {'address1': '163 Ralph Ave', 'address2': '', ...
# 11  {'address1': '19 Commerce St', 'address2': '',...
# 12  {'address1': '68 Dean St', 'address2': '', 'ad...
# 13  {'address1': '42-15 Crescent St', 'address2': ...
# 14  {'address1': '76 Pearl St', 'address2': '', 'a...
# 15  {'address1': '351 Amsterdam Ave', 'address2': ...
# 16  {'address1': '223 E 14th St', 'address2': '', ...
# 17  {'address1': '260 5th Ave', 'address2': '', 'a...
# 18  {'address1': '160 Prince St', 'address2': '', ...
# 19  {'address1': '1844 Givan Ave', 'address2': '',...
# 20  {'address1': '936 Fulton St', 'address2': '', ...
# 21  {'address1': '43 N 5th St', 'address2': '', 'a...
# 22  {'address1': '548 Driggs Ave', 'address2': '',...
# 23  {'address1': '1226 Forest Ave', 'address2': No...
# 24  {'address1': '189 Spring St', 'address2': '', ...
# 25  {'address1': '1028 Amsterdam Ave', 'address2':...
# 26  {'address1': '116 MacDougal St', 'address2': '...
# 27  {'address1': '210 Flatbush Ave', 'address2': '...
# 28  {'address1': '2348 Arthur Ave', 'address2': ''...
# 29  {'address1': '356 Amboy Ave', 'address2': '', ...
# 30  {'address1': '535 Hudson St', 'address2': '', ...
# 31  {'address1': '66 Water St', 'address2': '', 'a...
# 32  {'address1': '818 Franklin Ave', 'address2': '...
# 33  {'address1': '895 Annadale Rd', 'address2': ''...
# 34  {'address1': '28 Greenwich Ave', 'address2': '...
# 35  {'address1': '88 Hudson St', 'address2': '', '...
# 36  {'address1': '308 East 78th St', 'address2': '...
# 37  {'address1': '33 Main St', 'address2': '', 'ad...
# 38  {'address1': '630 Flushing Ave', 'address2': '...
# 39  {'address1': '1652 2nd Ave', 'address2': None,...
# 40  {'address1': '366 Myrtle Ave', 'address2': '',...
# 41  {'address1': '29-14 23rd Ave', 'address2': '',...
# 42  {'address1': '482 3rd Ave', 'address2': '', 'a...
# 43  {'address1': '31 Greenpoint Ave', 'address2': ...
# 44  {'address1': None, 'address2': None, 'address3...
# 45  {'address1': '279 Church St', 'address2': '', ...
# 46  {'address1': '405 Amsterdam Ave', 'address2': ...
# 47  {'address1': '139 Smith St', 'address2': None,...
# 48  {'address1': '3839 Bell Blvd', 'address2': '',...
# 49  {'address1': '353 W 14th St', 'address2': '', ...
#
#                                   name         phone price  rating  \
# 0                        Levain Bakery  +12128746080    $$     4.5
# 1                  Gooey on The Inside  +16469720409     $     4.0
# 2                         Schmackary's  +16468019866     $     4.0
# 3                             Chip NYC  +19177450101    $$     4.0
# 4                        Levain Bakery  +16464550952    $$     4.5
# 5                             Chip NYC  +19295220800   NaN     4.5
# 6                   The Cookie Connect  +12018225339    $$     4.5
# 7                           City Cakes  +16466882286    $$     4.5
# 8                        Ben's Cookies  +16465901156     $     3.5
# 9                         Bang Cookies  +18888348885     $     4.5
# 10                Sofia & Grace Cookie  +17184508034     $     4.5
# 11                      Milk & Cookies  +12122431640     $     3.5
# 12                    One Girl Cookies  +12126754996    $$     4.0
# 13                            Chip NYC  +19177450101   NaN     4.0
# 14                    Insomnia Cookies  +19292587762     $     3.5
# 15                       Levain Bakery  +12128746080    $$     4.5
# 16                     Fat Cat Kitchen  +12122351994     $     5.0
# 17                 Buttermilk Bakeshop  +13479873941    $$     4.5
# 18  Birdbath Neighborhood Green Bakery  +16465567720    $$     4.0
# 19          Golden Glow Cookie Company  +17183796223     $     4.5
# 20                      The Good Batch  +17186224000    $$     4.0
# 21                              Ovenly  +18888992213    $$     4.5
# 22                     Woops! BakeShop  +17183844410     $     4.0
# 23                      The Cookie Jar  +17184483500    $$     4.0
# 24              Dominique Ansel Bakery  +12122192773    $$     4.0
# 25                    Insomnia Cookies  +19179354257     $     3.0
# 26                    Insomnia Cookies  +19178770659     $     3.5
# 27                              Ovenly  +18888992213    $$     4.0
# 28             Madonia Brothers Bakery  +17182955573     $     4.5
# 29  La Bonbonniere's Cookie Jar Bakery  +17326360121    $$     4.0
# 30               Sweet Corner Bakeshop  +12122068500    $$     4.0
# 31            Jacques Torres Chocolate  +17188759772    $$     4.0
# 32                     Butter & Scotch  +13473508899    $$     4.0
# 33      Sweet Sweet Sue's Cupcake Cafe  +17189662253   $$$     4.0
# 34                  Mah-Ze-Dahr Bakery  +12124989810    $$     4.5
# 35                         Baking Mama  +12016830854    $$     4.5
# 36                          Orwasher's  +12122886569    $$     4.5
# 37                    One Girl Cookies  +12126754996    $$     3.5
# 38                 Krumville Bake Shop  +19174067447    $$     5.0
# 39                 Two Little Red Hens  +12124520476    $$     4.5
# 40                 Brooklyn Sweet Spot  +17185222577    $$     4.0
# 41                   Sugar & Water NYC  +17164662030   NaN     4.0
# 42                    Insomnia Cookies  +19292266392     $     3.5
# 43                              Ovenly  +18888992213    $$     4.0
# 44                    Boomshakalaka NY  +19176908830     $     4.5
# 45                               Baked  +12127750345    $$     4.0
# 46                    Insomnia Cookies  +19292394768     $     3.5
# 47                        Mia's Bakery  +13479873194     $     4.5
# 48                 The French Workshop  +17182240700    $$     4.5
# 49                   Gansevoort Market  +16464498400    $$     4.0
#
#     review_count        transactions  \
# 0           7388                  []
# 1            101  [pickup, delivery]
# 2           1786  [pickup, delivery]
# 3            502                  []
# 4            650                  []
# 5             24  [pickup, delivery]
# 6            137                  []
# 7            589            [pickup]
# 8            163  [pickup, delivery]
# 9            190                  []
# 10            36  [pickup, delivery]
# 11           535                  []
# 12           254                  []
# 13            46  [pickup, delivery]
# 14           179  [pickup, delivery]
# 15           378                  []
# 16           136  [pickup, delivery]
# 17           119  [pickup, delivery]
# 18           234                  []
# 19            26                  []
# 20           147                  []
# 21            16                  []
# 22           193  [pickup, delivery]
# 23           138                  []
# 24          4096                  []
# 25           103  [pickup, delivery]
# 26           231  [pickup, delivery]
# 27            49                  []
# 28           219                  []
# 29            37                  []
# 30           177  [pickup, delivery]
# 31           515  [pickup, delivery]
# 32           446  [pickup, delivery]
# 33            26                  []
# 34           208                  []
# 35            61  [pickup, delivery]
# 36           350                  []
# 37           226                  []
# 38            12                  []
# 39          2392                  []
# 40            69            [pickup]
# 41            66  [pickup, delivery]
# 42           312  [pickup, delivery]
# 43           177                  []
# 44             2                  []
# 45           292  [delivery, pickup]
# 46           298  [pickup, delivery]
# 47           538  [pickup, delivery]
# 48           766                  []
# 49           249                  []
#
#                                                   url
# 0   https://www.yelp.com/biz/levain-bakery-new-yor...
# 1   https://www.yelp.com/biz/gooey-on-the-inside-n...
# 2   https://www.yelp.com/biz/schmackarys-new-york?...
# 3   https://www.yelp.com/biz/chip-nyc-astoria?adju...
# 4   https://www.yelp.com/biz/levain-bakery-new-yor...
# 5   https://www.yelp.com/biz/chip-nyc-astoria-4?ad...
# 6   https://www.yelp.com/biz/the-cookie-connect-bl...
# 7   https://www.yelp.com/biz/city-cakes-new-york?a...
# 8   https://www.yelp.com/biz/bens-cookies-new-york...
# 9   https://www.yelp.com/biz/bang-cookies-jersey-c...
# 10  https://www.yelp.com/biz/sofia-and-grace-cooki...
# 11  https://www.yelp.com/biz/milk-and-cookies-new-...
# 12  https://www.yelp.com/biz/one-girl-cookies-broo...
# 13  https://www.yelp.com/biz/chip-nyc-long-island-...
# 14  https://www.yelp.com/biz/insomnia-cookies-new-...
# 15  https://www.yelp.com/biz/levain-bakery-new-yor...
# 16  https://www.yelp.com/biz/fat-cat-kitchen-new-y...
# 17  https://www.yelp.com/biz/buttermilk-bakeshop-b...
# 18  https://www.yelp.com/biz/birdbath-neighborhood...
# 19  https://www.yelp.com/biz/golden-glow-cookie-co...
# 20  https://www.yelp.com/biz/the-good-batch-brookl...
# 21  https://www.yelp.com/biz/ovenly-brooklyn-9?adj...
# 22  https://www.yelp.com/biz/woops-bakeshop-brookl...
# 23  https://www.yelp.com/biz/the-cookie-jar-staten...
# 24  https://www.yelp.com/biz/dominique-ansel-baker...
# 25  https://www.yelp.com/biz/insomnia-cookies-new-...
# 26  https://www.yelp.com/biz/insomnia-cookies-new-...
# 27  https://www.yelp.com/biz/ovenly-brooklyn-8?adj...
# 28  https://www.yelp.com/biz/madonia-brothers-bake...
# 29  https://www.yelp.com/biz/la-bonbonnieres-cooki...
# 30  https://www.yelp.com/biz/sweet-corner-bakeshop...
# 31  https://www.yelp.com/biz/jacques-torres-chocol...
# 32  https://www.yelp.com/biz/butter-and-scotch-bro...
# 33  https://www.yelp.com/biz/sweet-sweet-sues-cupc...
# 34  https://www.yelp.com/biz/mah-ze-dahr-bakery-ne...
# 35  https://www.yelp.com/biz/baking-mama-hoboken?a...
# 36  https://www.yelp.com/biz/orwashers-new-york?ad...
# 37  https://www.yelp.com/biz/one-girl-cookies-broo...
# 38  https://www.yelp.com/biz/krumville-bake-shop-b...
# 39  https://www.yelp.com/biz/two-little-red-hens-n...
# 40  https://www.yelp.com/biz/brooklyn-sweet-spot-b...
# 41  https://www.yelp.com/biz/sugar-and-water-nyc-a...
# 42  https://www.yelp.com/biz/insomnia-cookies-new-...
# 43  https://www.yelp.com/biz/ovenly-brooklyn?adjus...
# 44  https://www.yelp.com/biz/boomshakalaka-ny-broo...
# 45  https://www.yelp.com/biz/baked-new-york?adjust...
# 46  https://www.yelp.com/biz/insomnia-cookies-new-...
# 47  https://www.yelp.com/biz/mias-bakery-brooklyn?...
# 48  https://www.yelp.com/biz/the-french-workshop-b...
# 49  https://www.yelp.com/biz/gansevoort-market-new...

# %%
df1['price_num'] = df1['price'].str.len()

print(df1.describe())
print('\n')
print(df1["rating"].corr(df1["review_count"]))
print('\n')
print(df1["price_num"].corr(df1["review_count"]))
print('\n')
print(df1["name"].unique())
print('\n')
print(df1["name"].value_counts())
# Out:
#            distance     rating  review_count  price_num
# count     50.000000  50.000000     50.000000  47.000000
# mean    7112.228624   4.140000    517.680000   1.659574
# std     6715.930496   0.416986   1201.726402   0.522394
# min      361.241192   3.000000      2.000000   1.000000
# 25%     3058.688660   4.000000     77.000000   1.000000
# 50%     4074.934782   4.000000    191.500000   2.000000
# 75%     8780.637439   4.500000    371.000000   2.000000
# max    29575.852855   5.000000   7388.000000   3.000000
#
#
# 0.10156117844054108
#
#
# 0.12623217268834708
#
#
# ['Levain Bakery' 'Gooey on The Inside' "Schmackary's" 'Chip NYC'
#  'The Cookie Connect' 'City Cakes' "Ben's Cookies" 'Bang Cookies'
#  'Sofia & Grace Cookie' 'Milk & Cookies' 'One Girl Cookies'
#  'Insomnia Cookies' 'Fat Cat Kitchen' 'Buttermilk Bakeshop'
#  'Birdbath Neighborhood Green Bakery' 'Golden Glow Cookie Company'
#  'The Good Batch' 'Ovenly' 'Woops! BakeShop' 'The Cookie Jar'
#  'Dominique Ansel Bakery' 'Madonia Brothers Bakery'
#  "La Bonbonniere's Cookie Jar Bakery" 'Sweet Corner Bakeshop'
#  'Jacques Torres Chocolate' 'Butter & Scotch'
#  "Sweet Sweet Sue's Cupcake Cafe" 'Mah-Ze-Dahr Bakery' 'Baking Mama'
#  "Orwasher's" 'Krumville Bake Shop' 'Two Little Red Hens'
#  'Brooklyn Sweet Spot' 'Sugar & Water NYC' 'Boomshakalaka NY' 'Baked'
#  "Mia's Bakery" 'The French Workshop' 'Gansevoort Market']
#
#
# Insomnia Cookies                      5
# Levain Bakery                         3
# Ovenly                                3
# Chip NYC                              3
# One Girl Cookies                      2
# Fat Cat Kitchen                       1
# Woops! BakeShop                       1
# Sweet Sweet Sue's Cupcake Cafe        1
# Golden Glow Cookie Company            1
# The Cookie Connect                    1
# Mah-Ze-Dahr Bakery                    1
# Krumville Bake Shop                   1
# Ben's Cookies                         1
# Baking Mama                           1
# The Cookie Jar                        1
# Two Little Red Hens                   1
# Gansevoort Market                     1
# City Cakes                            1
# Sugar & Water NYC                     1
# Madonia Brothers Bakery               1
# Milk & Cookies                        1
# Buttermilk Bakeshop                   1
# The Good Batch                        1
# Brooklyn Sweet Spot                   1
# Sofia & Grace Cookie                  1
# The French Workshop                   1
# Sweet Corner Bakeshop                 1
# Baked                                 1
# Birdbath Neighborhood Green Bakery    1
# Boomshakalaka NY                      1
# Mia's Bakery                          1
# Orwasher's                            1
# Jacques Torres Chocolate              1
# Butter & Scotch                       1
# Gooey on The Inside                   1
# Dominique Ansel Bakery                1
# Schmackary's                          1
# La Bonbonniere's Cookie Jar Bakery    1
# Bang Cookies                          1
# Name: name, dtype: int64

# %%
df1.groupby(["name", "review_count"]).sum()
# Out:
#                                                      distance  is_closed  \
# name                               review_count
# Baked                              292            1703.822384      False
# Baking Mama                        61             4623.493462      False
# Bang Cookies                       190            7086.973427      False
# Ben's Cookies                      163            3072.862531      False
# Birdbath Neighborhood Green Bakery 234            2356.123963      False
# Boomshakalaka NY                   2              1030.521157      False
# Brooklyn Sweet Spot                69             2363.025112      False
# Butter & Scotch                    446            4982.532803      False
# Buttermilk Bakeshop                119            3554.276424      False
# Chip NYC                           24            10525.026678      False
#                                    46             6713.521434      False
#                                    502            9209.974859      False
# City Cakes                         589            4099.618344      False
# Dominique Ansel Bakery             4096           2316.930739      False
# Fat Cat Kitchen                    136            3150.663284      False
# Gansevoort Market                  249            4050.251220      False
# Golden Glow Cookie Company         26            23040.016057      False
# Gooey on The Inside                101            1694.634909      False
# Insomnia Cookies                   103           11197.072687      False
#                                    179            1369.805360      False
#                                    231            2755.946567      False
#                                    298            8781.224910      False
#                                    312            4584.167682      False
# Jacques Torres Chocolate           515             361.241192      False
# Krumville Bake Shop                12             3943.950057      False
# La Bonbonniere's Cookie Jar Bakery 37            29575.852855      False
# Levain Bakery                      378            8554.436874      False
#                                    650           11553.808020      False
#                                    7388           8367.197123      False
# Madonia Brothers Bakery            219           18812.209299      False
# Mah-Ze-Dahr Bakery                 208            3329.046043      False
# Mia's Bakery                       538            2081.025886      False
# Milk & Cookies                     535            3053.964037      False
# One Girl Cookies                   226             406.124454      False
#                                    254            2041.536412      False
# Orwasher's                         350            8124.285814      False
# Ovenly                             16             3082.161926      False
#                                    49             3118.214401      False
#                                    177            3991.609125      False
# Schmackary's                       1786           6089.899672      False
# Sofia & Grace Cookie               36             6461.807142      False
# Sugar & Water NYC                  66            10268.986360      False
# Sweet Corner Bakeshop              177            3399.746991      False
# Sweet Sweet Sue's Cupcake Cafe     26            24029.455676      False
# The Cookie Connect                 137           20401.641775      False
# The Cookie Jar                     138           14487.620701      False
# The French Workshop                766           19919.887471      False
# The Good Batch                     147            3650.047257      False
# Two Little Red Hens                2392           8778.875029      False
# Woops! BakeShop                    193            3464.313614      False
#
#                                                  rating  price_num
# name                               review_count
# Baked                              292              4.0        2.0
# Baking Mama                        61               4.5        2.0
# Bang Cookies                       190              4.5        1.0
# Ben's Cookies                      163              3.5        1.0
# Birdbath Neighborhood Green Bakery 234              4.0        2.0
# Boomshakalaka NY                   2                4.5        1.0
# Brooklyn Sweet Spot                69               4.0        2.0
# Butter & Scotch                    446              4.0        2.0
# Buttermilk Bakeshop                119              4.5        2.0
# Chip NYC                           24               4.5        0.0
#                                    46               4.0        0.0
#                                    502              4.0        2.0
# City Cakes                         589              4.5        2.0
# Dominique Ansel Bakery             4096             4.0        2.0
# Fat Cat Kitchen                    136              5.0        1.0
# Gansevoort Market                  249              4.0        2.0
# Golden Glow Cookie Company         26               4.5        1.0
# Gooey on The Inside                101              4.0        1.0
# Insomnia Cookies                   103              3.0        1.0
#                                    179              3.5        1.0
#                                    231              3.5        1.0
#                                    298              3.5        1.0
#                                    312              3.5        1.0
# Jacques Torres Chocolate           515              4.0        2.0
# Krumville Bake Shop                12               5.0        2.0
# La Bonbonniere's Cookie Jar Bakery 37               4.0        2.0
# Levain Bakery                      378              4.5        2.0
#                                    650              4.5        2.0
#                                    7388             4.5        2.0
# Madonia Brothers Bakery            219              4.5        1.0
# Mah-Ze-Dahr Bakery                 208              4.5        2.0
# Mia's Bakery                       538              4.5        1.0
# Milk & Cookies                     535              3.5        1.0
# One Girl Cookies                   226              3.5        2.0
#                                    254              4.0        2.0
# Orwasher's                         350              4.5        2.0
# Ovenly                             16               4.5        2.0
#                                    49               4.0        2.0
#                                    177              4.0        2.0
# Schmackary's                       1786             4.0        1.0
# Sofia & Grace Cookie               36               4.5        1.0
# Sugar & Water NYC                  66               4.0        0.0
# Sweet Corner Bakeshop              177              4.0        2.0
# Sweet Sweet Sue's Cupcake Cafe     26               4.0        3.0
# The Cookie Connect                 137              4.5        2.0
# The Cookie Jar                     138              4.0        2.0
# The French Workshop                766              4.5        2.0
# The Good Batch                     147              4.0        2.0
# Two Little Red Hens                2392             4.5        2.0
# Woops! BakeShop                    193              4.0        1.0

# %% [markdown]
# ## Mapping
#
# Look at the initial Yelp example and try and make a map using Folium of the restaurants you retrieved. Be sure to also add popups to the markers giving some basic information such as name, rating and price.

# %%
coordinates = df1["coordinates"].to_dict()
coordinates_list = []
for key, values in coordinates.items():
    coordinates_list.append(values)
coordinates_list
# Out:
# [{'latitude': 40.7799404643263, 'longitude': -73.980282552649},
#  {'latitude': 40.72063, 'longitude': -73.99275},
#  {'latitude': 40.760153883881, 'longitude': -73.990944257291},
#  {'latitude': 40.7655337630129, 'longitude': -73.9192518515278},
#  {'latitude': 40.8049739, 'longitude': -73.9551513},
#  {'latitude': 40.7755748, 'longitude': -73.9095839},
#  {'latitude': 40.8366154, 'longitude': -74.1636902},
#  {'latitude': 40.74206, 'longitude': -73.99999},
#  {'latitude': 40.732962, 'longitude': -73.99093},
#  {'latitude': 40.75567, 'longitude': -74.04607},
#  {'latitude': 40.6844899, 'longitude': -73.92289},
#  {'latitude': 40.731812157368, 'longitude': -74.00443554356},
#  {'latitude': 40.687328, 'longitude': -73.990465},
#  {'latitude': 40.75009, 'longitude': -73.94062},
#  {'latitude': 40.70377, 'longitude': -74.0104099},
#  {'latitude': 40.781532, 'longitude': -73.979286},
#  {'latitude': 40.73314, 'longitude': -73.98607},
#  {'latitude': 40.6749461087063, 'longitude': -73.9816744176426},
#  {'latitude': 40.72596, 'longitude': -74.00143},
#  {'latitude': 40.87638, 'longitude': -73.83959},
#  {'latitude': 40.68254, 'longitude': -73.96331},
#  {'latitude': 40.71909, 'longitude': -73.96247},
#  {'latitude': 40.717529, 'longitude': -73.956409},
#  {'latitude': 40.6261618, 'longitude': -74.1305995},
#  {'latitude': 40.72522, 'longitude': -74.00291},
#  {'latitude': 40.8034309090793, 'longitude': -73.9636512732403},
#  {'latitude': 40.7297607, 'longitude': -74.0006247},
#  {'latitude': 40.68119, 'longitude': -73.97573},
#  {'latitude': 40.85438, 'longitude': -73.8884099},
#  {'latitude': 40.553173, 'longitude': -74.281593},
#  {'latitude': 40.734609, 'longitude': -74.006405},
#  {'latitude': 40.7032, 'longitude': -73.99145},
#  {'latitude': 40.669893909327, 'longitude': -73.9583220803651},
#  {'latitude': 40.539772, 'longitude': -74.176956},
#  {'latitude': 40.73503, 'longitude': -74.00002},
#  {'latitude': 40.7369377, 'longitude': -74.0300944},
#  {'latitude': 40.772197, 'longitude': -73.955062},
#  {'latitude': 40.703327, 'longitude': -73.990368},
#  {'latitude': 40.6998241, 'longitude': -73.9480982},
#  {'latitude': 40.777528, 'longitude': -73.9517869},
#  {'latitude': 40.6930261, 'longitude': -73.9715469},
#  {'latitude': 40.77456, 'longitude': -73.91361},
#  {'latitude': 40.74501, 'longitude': -73.97888},
#  {'latitude': 40.729904, 'longitude': -73.959579},
#  {'latitude': 40.69245, 'longitude': -73.99137},
#  {'latitude': 40.7186, 'longitude': -74.00472},
#  {'latitude': 40.783434, 'longitude': -73.977903},
#  {'latitude': 40.6870199, 'longitude': -73.9901299},
#  {'latitude': 40.765684008587, 'longitude': -73.7716380616753},
#  {'latitude': 40.7410154, 'longitude': -74.0046413}]

# %%
names = df1["name"].tolist()
names
# Out:
# ['Levain Bakery',
#  'Gooey on The Inside',
#  "Schmackary's",
#  'Chip NYC',
#  'Levain Bakery',
#  'Chip NYC',
#  'The Cookie Connect',
#  'City Cakes',
#  "Ben's Cookies",
#  'Bang Cookies',
#  'Sofia & Grace Cookie',
#  'Milk & Cookies',
#  'One Girl Cookies',
#  'Chip NYC',
#  'Insomnia Cookies',
#  'Levain Bakery',
#  'Fat Cat Kitchen',
#  'Buttermilk Bakeshop',
#  'Birdbath Neighborhood Green Bakery',
#  'Golden Glow Cookie Company',
#  'The Good Batch',
#  'Ovenly',
#  'Woops! BakeShop',
#  'The Cookie Jar',
#  'Dominique Ansel Bakery',
#  'Insomnia Cookies',
#  'Insomnia Cookies',
#  'Ovenly',
#  'Madonia Brothers Bakery',
#  "La Bonbonniere's Cookie Jar Bakery",
#  'Sweet Corner Bakeshop',
#  'Jacques Torres Chocolate',
#  'Butter & Scotch',
#  "Sweet Sweet Sue's Cupcake Cafe",
#  'Mah-Ze-Dahr Bakery',
#  'Baking Mama',
#  "Orwasher's",
#  'One Girl Cookies',
#  'Krumville Bake Shop',
#  'Two Little Red Hens',
#  'Brooklyn Sweet Spot',
#  'Sugar & Water NYC',
#  'Insomnia Cookies',
#  'Ovenly',
#  'Boomshakalaka NY',
#  'Baked',
#  'Insomnia Cookies',
#  "Mia's Bakery",
#  'The French Workshop',
#  'Gansevoort Market']

# %%
import folium
manhattan_map = folium.Map(location=[40.7589, -73.9851], zoom_start=11)
manhattan_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
points = []
for i in range(len(coordinates_list)):
    x = coordinates_list[i]["latitude"]
    y = coordinates_list[i]["longitude"]
    point = (x, y)
    points.append(point)
for p in points:
    lat = p[0]
    long = p[1]
    marker = folium.Marker(location=[lat, long])
    marker.add_to(manhattan_map)
manhattan_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
for i, p in enumerate(points):
    lat = p[0]
    long = p[1]
    name = names[i]
    popup_text = "Lattitude: {}, Longitude: {}".format(name,lat,long)
    popup = folium.Popup(popup_text, parse_html=True)
    marker = folium.Marker(location=[lat, long], popup=popup)
    marker.add_to(manhattan_map)
manhattan_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Summary
#
# Nice work! In this lab, you synthesized your skills for the day, making multiple API calls to Yelp in order to paginate through a results set, performing some basic exploratory analysis and then creating a nice map visual to display the results! Well done!
